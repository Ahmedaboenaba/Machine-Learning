# %% [markdown]
# # Linear Regression on Salary Expectations Dataset
#
# Simple linear regression model on 1 feature (Years of experience) and one target (Salary)
#
# This data is from kaggle with link:
# https://www.kaggle.com/api/v1/datasets/download/abhishek14398/salary-dataset-simple-linear-regression

# %% [markdown]
# ## Pipeline
# 1- Import Data & Necessary libraries
# 2- Exploratory Data Anlysis
# 3- Data preprocessing
#     * Feature Scaling
#     * Manipulating Missings if found
# 4- Data Splitting
# 5- Training and prediction
# 6- Validation
# 7- Model Evaluation

# %% [markdown]
# ### Import Data & Necessary libraries

# %%
# Data Manipulation
import pandas as pd
import numpy as np

#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Machine learning 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# Load data 
salary = pd.read_csv('/mnt/d/Self_Study/DEPI/4-ML/datasets/Salary_dataset.csv',)
salary.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
salary.info() 
#30 rows and 3 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
# Check for missing values
salary.isnull().sum()
#No missing Values
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# ### EDA

# %%
fig = plt.figure(figsize=(10,5))
sns.scatterplot(x=salary["YearsExperience"], y=salary["Salary"])
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Years of Experience vs Salary")
plt.show()

# %% [markdown]
# ### Data Splitting

# %%
X= salary.iloc[:,1:-1].values
y=salary.iloc[:,-1].values

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=11)

# %% [markdown]
# ### Training & Prediction

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Validation

# %%
y_pred = lin_reg.predict(x_test)

# %% [markdown]
# ### Model Evaluation

# %%
r2 = r2_score(y_test,y_pred)
print("R2 score: ", r2*100)
# Out:
# R2 score:  94.08827284776221

# %%
# Visualize data
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x=y_test, y=y_pred)
sns.lineplot(x=y_test, y=y_test, color='red') # Line for perfect prediction
plt.xlabel("Actual Salary")
plt.ylabel("Predicted Salary")
plt.title("Actual vs Predicted Salary")
plt.show()
